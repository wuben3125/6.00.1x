# %%
# Unit 13 - Pylab

# not too much substantial material; seems like an entry point into 6002x

# %%
# content:
    # plotting figures for linear, quadratic, cubic, exponential functions
    # plotting functions on the same figure/window
    # plotting on separate windows using plt.figure()
    # plot labels
    # plot titles
    # cleaning windows
    # changing axis limits
    # labels + legend
    # plotting figures in the same window
    # display details 
        # color and style of line
        # linewidth
    # using subplots
    # changing scale
        # linear
        # log
    # extended retirement savings example

# %%
# uncertainties:
    # matplotlib vs pylab vs pyplot:
        # https://stackoverflow.com/questions/16849483/which-is-the-recommended-way-to-plot-matplotlib-or-pylab
        # https://matplotlib.org/faq/usage_faq.html#matplotlib-pyplot-and-pylab-how-are-they-related
        # tl;dr - matplotlib.pyplot and pylab serve the same function (kinda), but the former is recommended for non-interactive plotting(?)

    # plotting in iPython and Jupyter vs in a Python console 
    # clearing displaay windows (necessary with Spyder)
    # pylab
    # plt.figure('a name or something')
    # plt.clf()
    # plt.xlabel('name'), plt.ylabel('name')
    # plt.title('title')
    # plt.plot(x, y, 'colorthing',  label = 'label', linewidth = 25)
    # plt.legend(loc = 'location') - ex: loc = 'upper left'
    # plt.legend()
    # color and style for labels: https://matplotlib.org/2.1.1/api/_as_gen/matplotlib.pyplot.plot.html
    # plt.subplot(212) - 2 rows, 1 column, 1st subplot
        # why is my legend so small that it can't fit two labels
    # plt.yscale('log')
        # docs: https://matplotlib.org/api/_as_gen/matplotlib.pyplot.yscale.html

# %%
mySamples = []
myLinear = []
myQuadratic = []
myCubic = []
myExponential = []

for i in range(0,30):
    mySamples.append(i)
    myLinear.append(i)
    myQuadratic.append(i**2)
    myCubic.append(i**3)
    myExponential.append(1.5**i)

# %%
import pylab as plt

# %%
plt.plot(mySamples, myLinear)

# %%
plt.plot(mySamples, myQuadratic)

# %%
# plot all graphs at same time
plt.plot(mySamples, myLinear)
plt.plot(mySamples, myQuadratic)
plt.plot(mySamples, myCubic)
plt.plot(mySamples, myExponential)

# janky scaling

# %%
# separating plots 
plt.figure('linear')
plt.plot(mySamples, myLinear)

plt.figure('exponential')
plt.plot(mySamples, myExponential)

# %%
plt.plot(mySamples, myQuadratic)
# separate figures only necessary when statements being executed in same 'block'

# %%
myOtherLinear = []
for i in myLinear:
    myOtherLinear.append(i + 5)
    
    
plt.figure('linear')
plt.plot(mySamples, myLinear)

plt.figure('exponential')
plt.plot(mySamples, myExponential)    
    
plt.figure('linear') # can add other functions to the same figure (maybe this is why the plot is shown last?)
plt.plot(mySamples, myOtherLinear)

# %%
# Plot labels
plt.figure('lin') # open up a figure
plt.xlabel('sample points')
plt.ylabel('linear function')
plt.plot(mySamples, myLinear)

plt.figure('quad') # open up a figure, override the others
plt.plot(mySamples, myQuadratic)

plt.figure('cube')
plt.plot(mySamples, myCubic)

plt.figure('expo')
plt.plot(mySamples, myExponential)

plt.figure('quad') # re-open a figure
plt.ylabel('quadratic function')
# Out:
# Text(0,0.5,'quadratic function')

# %%
# Plot titles

# simulating uncleared display windows
plt.figure('lin') # open up a figure
plt.xlabel('sample points')
plt.ylabel('linear function')
plt.plot(mySamples, myLinear)

plt.figure('quad') # open up a figure, override the others
plt.plot(mySamples, myQuadratic)

plt.figure('cube')
plt.plot(mySamples, myCubic)

plt.figure('expo')
plt.plot(mySamples, myExponential)

plt.figure('quad') # re-open a figure
plt.ylabel('quadratic function')


# "new" plots
plt.figure('lin')
plt.plot(mySamples, myLinear)

plt.figure('quad')
plt.plot(mySamples, myQuadratic)

plt.figure('cube')
plt.plot(mySamples, myCubic)

plt.figure('expo')
plt.plot(mySamples, myCubic)

# reopening figures and titling them
plt.figure('lin')
plt.title('Linear')

plt.figure('quad')
plt.title('Quadratic')

plt.figure('cube')
plt.title('Cubic')

plt.figure('expo')
plt.title('Exponential')
# Out:
# Text(0.5,1,'Exponential')

# %%
# cleaning windows

# simulating uncleared display windows
plt.figure('lin') # open up a figure
plt.xlabel('sample points')
plt.ylabel('linear function')
plt.plot(mySamples, myLinear)

plt.figure('quad') # open up a figure, override the others
plt.plot(mySamples, myQuadratic)

plt.figure('cube')
plt.plot(mySamples, myCubic)

plt.figure('expo')
plt.plot(mySamples, myExponential)

plt.figure('quad') # re-open a figure
plt.ylabel('quadratic function')


# "new" plots
plt.figure('lin')
plt.clf()
plt.plot(mySamples, myLinear)

plt.figure('quad')
plt.clf()
plt.plot(mySamples, myQuadratic)

plt.figure('cube')
plt.clf()
plt.plot(mySamples, myCubic)

plt.figure('expo')
plt.clf()
plt.plot(mySamples, myCubic)

# reopening figures and titling them
plt.figure('lin')
plt.title('Linear')

plt.figure('quad')
plt.title('Quadratic')

plt.figure('cube')
plt.title('Cubic')

plt.figure('expo')
plt.title('Exponential')
# Out:
# Text(0.5,1,'Exponential')

# %%
# changing limits on axes - useful for comparisons
plt.figure('lin')
plt.clf()
plt.ylim(0,1000)
plt.plot(mySamples, myLinear)

plt.figure('quad')
plt.clf()
plt.ylim(0,1000)
plt.plot(mySamples, myQuadratic)

plt.figure('lin')
plt.title('Linear')

plt.figure('quad')
plt.title('Quadratic')
# Out:
# Text(0.5,1,'Quadratic')

# %%
# plotting two figures in the same window - useful for comparisons
plt.figure('lin quad')
plt.clf()
plt.plot(mySamples, myLinear)
plt.plot(mySamples, myQuadratic)

plt.figure('cube exp')
plt.clf()
plt.plot(mySamples, myCubic)
plt.plot(mySamples, myExponential)

plt.figure('lin quad')
plt.title('Linear and Quadratic')

plt.figure('cube exp')
plt.title('Cubic and Exponential')
# Out:
# Text(0.5,1,'Cubic and Exponential')

# %%
# adding legends/keys
# plotting two figures in the same window - useful for comparisons
plt.figure('lin quad')
plt.clf()
plt.plot(mySamples, myLinear, label = 'Linear')
plt.plot(mySamples, myQuadratic, label = 'Quadratic')
plt.legend(loc = 'upper left') # legend location 
plt.title('Linear and Quadratic')

plt.figure('cube exp')
plt.clf()
plt.plot(mySamples, myCubic, label = 'Cubic')
plt.plot(mySamples, myExponential, label = 'Exponential')
plt.legend() # legend location 
plt.title('Cubic and Exponential')
# Out:
# Text(0.5,1,'Cubic and Exponential')

# %%
# Display details
# documentation: https://matplotlib.org/2.1.1/api/_as_gen/matplotlib.pyplot.plot.html

plt.figure('lin quad')
plt.clf()
plt.plot(mySamples, myLinear, 'b-', label = 'Linear')
plt.plot(mySamples, myQuadratic, 'ro', label = 'Quadratic')
plt.legend(loc = 'upper left')
plt.title('Linear and Quadratic')

plt.figure('cube exp')
plt.clf()
plt.plot(mySamples, myCubic, 'g^', label = 'Cubic')
plt.plot(mySamples, myExponential, 'r--', label = 'Exponential')
plt.legend()
plt.title('Cubic and Exponential')
# Out:
# Text(0.5,1,'Cubic and Exponential')

# %%
# Line width
# Display details
# documentation: https://matplotlib.org/2.1.1/api/_as_gen/matplotlib.pyplot.plot.html

plt.figure('lin quad')
plt.clf()
plt.plot(mySamples, myLinear, 'b-', label = 'Linear', linewidth = 2.0)
plt.plot(mySamples, myQuadratic, 'ro', label = 'Quadratic', linewidth = 3.0)
plt.legend(loc = 'upper left')
plt.title('Linear and Quadratic')

plt.figure('cube exp')
plt.clf()
plt.plot(mySamples, myCubic, 'g^', label = 'Cubic', linewidth = 4.0)
plt.plot(mySamples, myExponential, 'r--', label = 'Exponential', linewidth = 25.0)
plt.legend()
plt.title('Cubic and Exponential')
# Out:
# Text(0.5,1,'Cubic and Exponential')

# %%
# Using subplots
# plt.figure('lin quad cubic')
plt.figure('lin quad')

plt.clf()
# plt.subplot(311)
plt.subplot(211) # two rows, one column , the first subplot
plt.ylim(0,1600)
plt.plot(mySamples, myLinear, 'b-', label = 'linear', linewidth = 2.0)

# plt.subplot(312)
plt.subplot(212) # two rows, one column, the second subplot
plt.ylim(0,1600)
plt.plot(mySamples, myQuadratic, 'r', label = 'quadratic', linewidth = 3.0)

# plt.subplot(313)
# plt.ylim(0,1600)
# plt.plot(mySamples, myCubic, 'k', label = 'cubic', linewidth = 4.0)

plt.legend(loc = 'upper left')
# plt.title('Linear, Quadratic, and Cubic')
plt.title('Linear and Quadratic')


plt.figure('cube exp')
plt.clf()
plt.subplot(121) # one row, two columns, the first subplot
plt.ylim(0,140000)
plt.plot(mySamples, myCubic, 'g--', label = 'cubic', linewidth = 4.0)

plt.subplot(122) # one row, two columns, the second subplot
plt.ylim(0,140000)
plt.plot(mySamples, myExponential, 'r', label = 'exponential', linewidth = 5.0)

plt.legend()
plt.title('cubic and exponential')
# Out:
# Text(0.5,1,'cubic and exponential')

# %%
# changing scales
plt.figure('cube exp log')
plt.clf()
plt.plot(mySamples, myCubic, 'g--', label = 'cubic', linewidth = 2.0)
plt.plot(mySamples, myExponential, 'r', label = 'exponential', linewidth = 4.0)
plt.yscale('log')
plt.legend()
plt.title('Cubic and Exponential')

plt.figure('cube exp linear')
plt.clf()
plt.plot(mySamples, myCubic, 'g--', label = 'cubic', linewidth = 2.0)
plt.plot(mySamples, myExponential, 'r', label = 'exponential', linewidth = 4.0)
plt.yscale('linear') # default scale
plt.legend()
plt.title('Cubic and Exponential')
# Out:
# Text(0.5,1,'Cubic and Exponential')

# %%
# savings retirement example
def retire(monthly, rate, terms):
    savings = [0]
    base = [0]
    mRate = rate/12
    for i in range(terms):
        base += [i] # x values
        savings += [savings[-1]*(1 + mRate) + monthly] # y values
    return base, savings

# %%
# displaying long term result of different monthly inputs
def displayRetireWMonthlies(monthlies, rate, terms):
    '''
    monthlies: a list of monthly money amounts to be stored
    rate: yearly interest rate
    terms: number of months to pass
    '''
    plt.figure('retireMonth')
    plt.clf()
    for monthly in monthlies:
        xvals, yvals = retire(monthly, rate, terms)
        plt.plot(xvals, yvals,
                label = 'retire: $'+ str(monthly) + "/month")
        plt.legend(loc = 'upper left')
        
displayRetireWMonthlies([500, 600, 700, 800, 900, 1000, 1100], 0.05, 40*12)

# %%
# displaying long term results of different interest rates
def displayRetireWRates(month, rates, terms):
    '''
    month: monthly money amount to be stored
    rates: list of yearly interest rates
    terms: number of months to pass
    '''
    plt.figure('retireRate')
    plt.clf()
    for rate in rates:
        xvals, yvals = retire(month, rate, terms)
        plt.plot(xvals, yvals,
                label = 'retire: $'+ str(month) + ': ' + \
                        str(int(rate*100)) + "%")
        plt.legend(loc = 'upper left')
        
displayRetireWRates(800, [0.03, 0.05, 0.07], 40*12)

# %%
# displaying results of different monthly inputs and interest rates
def displayRetireWMonthsAndRates(monthlies, rates, terms):
    plt.figure('retireBoth')
    plt.clf()
    plt.xlim(30*12, 40*12)
    for monthly in monthlies:
        for rate in rates:
            xvals, yvals = retire(monthly, rate, terms)
            plt.plot(xvals, yvals, 
                    label = '$'+str(monthly) + ':' \
                    + str(int(rate*100))+"%")
            plt.legend(loc = 'upper left')
            
displayRetireWMonthsAndRates([500, 700, 900, 1100], [.03, .05, .07], 40*12)

# %%
# displaying results intelligently
# displaying results of different monthly inputs and interest rates
def displayRetireWMonthsAndRates(monthlies, rates, terms):
    plt.figure('retireBoth')
    plt.clf()
    plt.xlim(30*12, 40*12)
    
    monthLabels = ['r', 'b', 'g', 'k'] # one for each monthly deposit rate
    rateLabels = ['-', '^', '--'] # one for each interest rate
    
    for i in range(len(monthlies)):
        monthly = monthlies[i]
        monthLabel = monthLabels[i%len(monthLabels)]
        for j in range(len(rates)):
            rate = rates[j]
            rateLabel = rateLabels[j%len(rateLabels)]
            xvals, yvals = retire(monthly, rate, terms)
            plt.plot(xvals, yvals,
                     monthLabel+rateLabel, # combined color and style
                    label = '$'+str(monthly) + ':' \
                    + str(int(rate*100))+"%",
                    linewidth = 1.0)
            plt.legend(loc = 'upper left')
            
displayRetireWMonthsAndRates([500, 700, 900, 1100], [.03, .05, .07], 40*12)
